# %% [markdown]
# <a href="https://colab.research.google.com/github/jwoo13/Computer1/blob/main/5_%EA%B4%80%EA%B3%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# %%
A = {1,2,3}
B = {2,3,4}

R = {(1,2),(2,3),(3,2),(3,4)}

print("관계 R:",R)
# Out:
# 관계 R: {(2, 3), (3, 2), (1, 2), (3, 4)}

# %%
A_list = sorted(A)
B_list = sorted(B)

relation_matrix = np.zeros((len(A_list), len(B_list)), dtype=int)

for i, a in enumerate(A_list):
    for j, b in enumerate(B_list):
        if (a, b) in R:
            relation_matrix[i, j] = 1
print("관계 행렬 (rows: A, columns: B):")
print(relation_matrix)
# Out:
# 관계 행렬 (rows: A, columns: B):
# [[1 0 0]
#  [0 1 0]
#  [1 0 1]]

# %%
# R: A -> B
# S: B -> C
C = {'x', 'y'}
S = {(2, 'x'), (3, 'y'), (4, 'x')}

# 합성 관계 R ◦ S
composed_relation = set()

for (a, b1) in R:
  for (b2, c) in S:
       if b1 == b2:
           composed_relation.add((a, c))

print("\n합성 관계 R ◦ S:", composed_relation)
# Out:
# 합성 관계 R ◦ S: {(2, 'y'), (3, 'x'), (1, 'x')}
